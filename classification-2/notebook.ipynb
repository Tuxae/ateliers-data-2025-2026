# %%
import pandas as pd
import numpy as np

pd.options.plotting.backend = "plotly"

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'malignant'],
#       dtype='object')

# %%
df.plot(kind='hist', x='texture_mean', color='malignant', opacity=0.7)
# Out:
# <div>                            <div id="980da1c5-6db9-4a25-a554-2d07e470b874" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("980da1c5-6db9-4a25-a554-2d07e470b874")) {                    Plotly.newPlot(                        "980da1c5-6db9-4a25-a554-2d07e470b874",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"malignant=True\u003cbr\u003etexture_mean=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"x":[10.38,17.77,21.25,20.38,14.34,15.7,19.98,20.83,21.82,24.04,23.24,17.89,24.8,23.95,22.61,27.54,20.13,20.68,22.15,14.26,23.04,21.38,16.4,2
# ...

# %%
df.plot(kind='hist', x='smoothness_mean', color='malignant', opacity=0.7)
# Out:
# <div>                            <div id="9a6d07e5-51b3-4098-835b-f9d5e8830063" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a6d07e5-51b3-4098-835b-f9d5e8830063")) {                    Plotly.newPlot(                        "9a6d07e5-51b3-4098-835b-f9d5e8830063",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"malignant=True\u003cbr\u003esmoothness_mean=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"x":[0.1184,0.08474,0.1096,0.1425,0.1003,0.1278,0.09463,0.1189,0.1273,0.1186,0.08206,0.0971,0.0974,0.08401,0.1131,0.1139,0.09867,0.117,0.0
# ...

# %%
df.plot(kind='scatter', x='texture_mean', y='smoothness_mean', color='malignant', opacity=0.7)
# Out:
# <div>                            <div id="75a19e2c-cde1-4483-b06f-2bfb7449e47f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75a19e2c-cde1-4483-b06f-2bfb7449e47f")) {                    Plotly.newPlot(                        "75a19e2c-cde1-4483-b06f-2bfb7449e47f",                        [{"hovertemplate":"malignant=True\u003cbr\u003etexture_mean=%{x}\u003cbr\u003esmoothness_mean=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"True","orientation":"v","showlegend":true,"x":[10.38,17.77,21.25,20.38,14.34,15.7,19.98,20.83,21.82,24.04,23.24,17.89,24.8,23.95,22.61,27.54,20.13,20.68,22.15,14.26,23.04,21.38,16.4,21.53,20.25,25.27,15.05,25.11,18.7,23.9
# ...

# %%
X = df.drop(columns=['malignant'])
y = df['malignant']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12345) # stratified

# %%
y.value_counts(normalize=True), y_train.value_counts(normalize=True), y_test.value_counts(normalize=True)
# Out:
# (malignant
#  False    0.627417
#  True     0.372583
#  Name: proportion, dtype: float64,
#  malignant
#  False    0.626374
#  True     0.373626
#  Name: proportion, dtype: float64,
#  malignant
#  False    0.631579
#  True     0.368421
#  Name: proportion, dtype: float64)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
